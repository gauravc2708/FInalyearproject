# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Name                         10000 non-null object
# E-mail                       10000 non-null object
# Preferred Position           10000 non-null object
# Expected Salary              10000 non-null object
# Skills                       10000 non-null object
# CGPA                         10000 non-null float64
# 10th Percentage              10000 non-null float64
# 12th Percentage              10000 non-null float64
# Branch                       10000 non-null object
# Certifications               1970 non-null float64
# Level of Participation       975 non-null object
# Communication Proficiency    10000 non-null int64
# Programming Languages        10000 non-null object
# Extraversion                 10000 non-null int64
# Agreeableness                10000 non-null int64
# Openness                     10000 non-null int64
# ...

# %%
df['index'] = df.index

# %%
df.head()
# Out:
#                   Name                       E-mail  \
# 0       Tabor Fomichyov  tfomichyov0@opensource.org
# 1       Binnie Warhurst         bwarhurst1@ning.com
# 2         Hatty Dewbury           hdewbury2@umn.edu
# 3  Wallas Van Rembrandt             wvan3@google.ru
# 4       Clayton Durning       cdurning4@shop-pro.jp
#
#               Preferred Position Expected Salary                   Skills  \
# 0            Office Assistant IV       $31554.87       Clinical Nutrition
# 1            Account Coordinator       $34036.10            MySQL Cluster
# 2        Assistant Media Planner       $33612.89         Alumni Relations
# 3                Legal Assistant       $21501.30                Gstreamer
# 4  Analog Circuit Design manager       $30828.03  Political Risk Analysis
#
#    CGPA  10th Percentage  12th Percentage      Branch  Certifications  ...    \
# 0  6.60            54.45            65.31          IT             NaN  ...
# ...

# %%
cols = df.columns.tolist()

# %%
cols
# Out:
# ['Name ',
#  'E-mail',
#  'Preferred Position',
#  'Expected Salary',
#  'Skills',
#  'CGPA',
#  '10th Percentage',
#  '12th Percentage',
#  'Branch',
#  'Certifications',
#  'Level of Participation',
#  'Communication Proficiency',
#  'Programming Languages',
#  'Extraversion',
#  'Agreeableness',
#  'Openness',
#  'Conscientiousness',
#  'Neuroticism',
#  'Attendance %',
#  'Employeed',
#  'index']

# %%
cols = cols[-1:] + cols[:-1]

# %%
cols
# Out:
# ['index',
#  'Name ',
#  'E-mail',
#  'Preferred Position',
#  'Expected Salary',
#  'Skills',
#  'CGPA',
#  '10th Percentage',
#  '12th Percentage',
#  'Branch',
#  'Certifications',
#  'Level of Participation',
#  'Communication Proficiency',
#  'Programming Languages',
#  'Extraversion',
#  'Agreeableness',
#  'Openness',
#  'Conscientiousness',
#  'Neuroticism',
#  'Attendance %',
#  'Employeed']

# %%
df = df[cols]

# %%
df.head()
# Out:
#    index                 Name                       E-mail  \
# 0      0       Tabor Fomichyov  tfomichyov0@opensource.org
# 1      1       Binnie Warhurst         bwarhurst1@ning.com
# 2      2         Hatty Dewbury           hdewbury2@umn.edu
# 3      3  Wallas Van Rembrandt             wvan3@google.ru
# 4      4       Clayton Durning       cdurning4@shop-pro.jp
#
#               Preferred Position Expected Salary                   Skills  \
# 0            Office Assistant IV       $31554.87       Clinical Nutrition
# 1            Account Coordinator       $34036.10            MySQL Cluster
# 2        Assistant Media Planner       $33612.89         Alumni Relations
# 3                Legal Assistant       $21501.30                Gstreamer
# 4  Analog Circuit Design manager       $30828.03  Political Risk Analysis
#
#    CGPA  10th Percentage  12th Percentage      Branch    ...      \
# 0  6.60            54.45            65.31          IT    ...
# ...

# %%
df['index']=df['index']+1

# %%
df.head()
# Out:
#    index                 Name                       E-mail  \
# 0      1       Tabor Fomichyov  tfomichyov0@opensource.org
# 1      2       Binnie Warhurst         bwarhurst1@ning.com
# 2      3         Hatty Dewbury           hdewbury2@umn.edu
# 3      4  Wallas Van Rembrandt             wvan3@google.ru
# 4      5       Clayton Durning       cdurning4@shop-pro.jp
#
#               Preferred Position Expected Salary                   Skills  \
# 0            Office Assistant IV       $31554.87       Clinical Nutrition
# 1            Account Coordinator       $34036.10            MySQL Cluster
# 2        Assistant Media Planner       $33612.89         Alumni Relations
# 3                Legal Assistant       $21501.30                Gstreamer
# 4  Analog Circuit Design manager       $30828.03  Political Risk Analysis
#
#    CGPA  10th Percentage  12th Percentage      Branch    ...      \
# 0  6.60            54.45            65.31          IT    ...
# ...

# %%
df.to_csv('df.csv')
